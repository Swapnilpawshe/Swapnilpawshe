# %% [markdown]
# # STOCK MARKET ANALYSIS

# %%
import pandas as pd
import yfinance as yf
import datetime
from datetime import date, timedelta
import plotly.graph_objects as go
import plotly.express as px
today = date.today()

d1 = today.strftime("%Y-%m-%d")
end_date =d1
d2 = date.today() - timedelta(days=360)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2


data = yf.download('AAPL', start= start_date,
                           end=end_date,
                           progress=False)
print(data.tail())
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-09-07  154.820007  156.669998  153.610001  155.960007  155.960007
# 2022-09-08  154.639999  156.360001  152.679993  154.460007  154.460007
# 2022-09-09  155.470001  157.820007  154.750000  157.369995  157.369995
# 2022-09-12  159.589996  164.259995  159.300003  163.429993  163.429993
# 2022-09-13  159.899994  160.539993  154.949997  155.109894  155.109894
#
#                Volume
# Date
# 2022-09-07   87449600
# 2022-09-08   84923800
# 2022-09-09   68028800
# 2022-09-12  104806600
# 2022-09-13   74582623

# %%
#In above data date is  not a column its a index we have to make date as column and seperate index

# %%
data["Date"]= data.index
data = data [["Date","Open","High","Low","Close","Adj Close","Volume"]]
data.reset_index(drop=True, inplace=True)
print(data.head())
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2021-09-20  143.800003  144.839996  141.270004  142.940002  142.143494
# 1 2021-09-21  143.929993  144.600006  142.779999  143.429993  142.630737
# 2 2021-09-22  144.449997  146.429993  143.699997  145.850006  145.037277
# 3 2021-09-23  146.649994  147.080002  145.639999  146.830002  146.011841
# 4 2021-09-24  145.660004  147.470001  145.559998  146.919998  146.101318
#
#       Volume
# 0  123478900
# 1   75834000
# 2   76404300
# 3   64838200
# 4   53477900

# %% [markdown]
# # To visualize candlestick chart of google stock price

# %%
figure = go.Figure(data=[go.Candlestick(x=data["Date"],open=data["Open"], high= data["High"],
                                        low= data["Low"],close =data["Close"])])
figure.update_layout(title="Google Stock Price Analysis", xaxis_rangeslider_visible=False)
figure.show()
# Out:
# <div>                            <div id="7cbfee6e-bae7-4d2b-a2bc-90e16d873b7f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7cbfee6e-bae7-4d2b-a2bc-90e16d873b7f")) {                    Plotly.newPlot(                        "7cbfee6e-bae7-4d2b-a2bc-90e16d873b7f",                        [{"close":[142.94000244140625,143.42999267578125,145.85000610351562,146.8300018310547,146.9199981689453,145.3699951171875,141.91000366210938,142.8300018310547,141.5,142.64999389648438,139.13999938964844,141.11000061035156,142.0,143.2899932861328,142.89999389648438,142.80999755859375,141.50999450683594,140.91000366210938,143.75999450683594,144.83999633789062,146.5500030517578,148.75999450683594,149.25999450683594,149.47999572753906,148.69000244140625,148.6399993896
# ...

# %%
figure= px.bar(data, x= "Date", y="Close")
figure.show()
# Out:
# <div>                            <div id="90dedbe6-dfb1-4101-a958-812c76e51ca4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90dedbe6-dfb1-4101-a958-812c76e51ca4")) {                    Plotly.newPlot(                        "90dedbe6-dfb1-4101-a958-812c76e51ca4",                        [{"alignmentgroup":"True","hovertemplate":"Date=%{x}<br>Close=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2021-09-20T00:00:00","2021-09-21T00:00:00","2021-09-22T00:00:00","2021-09-23T00:00:00","2021-09-24T00:00:00","2021-09-27T00:00:00","2021-09-28T00:00:00","2021-09-29T00:00:00","2021-09-30T00:00:00","2021-10-01T00:00:00","2021
# ...

# %% [markdown]
# # TO ADD RANGE SLIDER WHICH IS HELPFULL TO ANALYZE THE STOCK MARKET BETWEEN TWO SPECIFIC POINT

# %%
figure =px.line(data, x="Date", y="Close",
               title ="Stock market analysis with Rangeslider")
figure.update_xaxes(rangeslider_visible=True)
figure.show()
# Out:
# <div>                            <div id="926d1ff2-e9b3-413c-ae00-a479be923199" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("926d1ff2-e9b3-413c-ae00-a479be923199")) {                    Plotly.newPlot(                        "926d1ff2-e9b3-413c-ae00-a479be923199",                        [{"hovertemplate":"Date=%{x}<br>Close=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2021-09-20T00:00:00","2021-09-21T00:00:00","2021-09-22T00:00:00","2021-09-23T00:00:00","2021-09-24T00:00:00","2021-09-27T00:00:00","2021-09-28T00:00:00","2021-09-29T00:00:00","2021-09-30T00:00:00","2021-10-01T00:00:00","2021-10-04T00:00:00","2021-10-05T
# ...

# %% [markdown]
# # Stock Market Analysis by Hiding Weekend Gaps

# %%
figure = px.scatter(data, x='Date', y='Close', range_x=['2021-07-12', '2022-09-12'],
                 title="Stock Market Analysis by Hiding Weekend Gaps")
figure.update_xaxes(
    rangebreaks=[
        dict(bounds=["sat", "sun"])
    ]
)
figure.show()
# Out:
# <div>                            <div id="6bf3d500-c06d-4118-91cd-d5eac364c27d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6bf3d500-c06d-4118-91cd-d5eac364c27d")) {                    Plotly.newPlot(                        "6bf3d500-c06d-4118-91cd-d5eac364c27d",                        [{"hovertemplate":"Date=%{x}<br>Close=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["2021-09-17T00:00:00","2021-09-20T00:00:00","2021-09-21T00:00:00","2021-09-22T00:00:00","2021-09-23T00:00:00","2021-09-24T00:00:00","2021-09-27T00:00:00","2021-09-28T00:00:00","2021-09-29T00:00:00","2021-09-30T00:00:00","2021-10-01T00:00:00","2021-10-04T00:00:00","2021-10-05T
# ...

# %% [markdown]
# # STOCK MARKET ANALYSIS WITH TIME PERIOD SELECTORS

# %%
figure = px.line(data, x='Date', y='Close', 
                 title='Stock Market Analysis with Time Period Selectors')
figure.update_xaxes(
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=3, label="3m", step="month", stepmode="backward"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
# Out:
# <div>                            <div id="4e0d224f-b27b-4a2c-9adb-db5d1445c086" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e0d224f-b27b-4a2c-9adb-db5d1445c086")) {                    Plotly.newPlot(                        "4e0d224f-b27b-4a2c-9adb-db5d1445c086",                        [{"hovertemplate":"Date=%{x}<br>Close=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2021-09-20T00:00:00","2021-09-21T00:00:00","2021-09-22T00:00:00","2021-09-23T00:00:00","2021-09-24T00:00:00","2021-09-27T00:00:00","2021-09-28T00:00:00","2021-09-29T00:00:00","2021-09-30T00:00:00","2021-10-01T00:00:00","2021-10-04T00:00:00","2021-10-05T
# ...
